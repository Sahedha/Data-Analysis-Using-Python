# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
#load the saved filr
model = load_model('/content/Model.h5')

# %%
#Load and preprocess the test image
test_image_path = ('/content/pred23.jpg')
img = image.load_img(test_image_path,target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array,axis=0)

# %%
#Add batch dimension
img_array /= 255.   #Normalize the pixel values   -zoomin/out
#Make predictions
prediction = model.predict(img_array)
#print the prediction
print(prediction)
# Out:
# 1/1 [==============================] - 0s 292ms/step
# [[0.5039846]]

# %%
#
if prediction < 0.5:
  print("Prediction: No Tumor (P robability: )",prediction[0][0])
else:
  print("Prediction: Tumor Present (Probability: )",prediction[0][0])
# Out:
# Prediction: Tumor Present (Probability: ) 0.5039846

# %% [markdown]
# **yes** **file**

# %%
#load the saved filr
model = load_model('/content/drive/MyDrive/Model.h5')

# %%
#Load and preprocess the test image in yess
test_image_path = ('/content/y30.jpg')
img = image.load_img(test_image_path,target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array,axis=0)

# %%
#Add batch dimension
img_array /= 255.   #Normalize the pixel values   -zoomin/out
#Make predictions
prediction = model.predict(img_array)
#print the prediction
print(prediction)
# Out:
# 1/1 [==============================] - 0s 324ms/step
# [[0.50477946]]

# %%
if prediction < 0.5:
  print("Prediction: No Tumor (P robability: )",prediction[0][0])
else:
  print("Prediction: Tumor Present (Probability: )",prediction[0][0])
# Out:
# Prediction: Tumor Present (Probability: ) 0.50477946

# %% [markdown]
# **No** **file**

# %%
#load the saved filr
model = load_model('/content/drive/MyDrive/Model.h5')

# %%
#Load and preprocess the test image in yess
test_image_path = ('/content/drive/MyDrive/Brain_Tumor_Detection/Train/no/no1009.jpg')
img = image.load_img(test_image_path,target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array,axis=0)

# %%
#Add batch dimension
img_array /= 255.   #Normalize the pixel values   -zoomin/out
#Make predictions
prediction = model.predict(img_array)
#print the prediction
print(prediction)
# Out:
# 1/1 [==============================] - 0s 111ms/step
# [[0.48770306]]

# %%
if prediction < 0.5:
  print("Prediction: No Tumor (P robability: )",prediction[0][0])
else:
  print("Prediction: Tumor Present (Probability: )",prediction[0][0])
# Out:
# Prediction: No Tumor (P robability: ) 0.48770306

# %% [markdown]
# **Test** - **Pred** **file**

# %%
#load the saved filr
model = load_model('/content/drive/MyDrive/Model.h5')

# %%
#Load and preprocess the test image in yess
test_image_path = ('/content/drive/MyDrive/Brain_Tumor_Detection/Test/pred/pred8.jpg')
img = image.load_img(test_image_path,target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array,axis=0)

# %%
#Add batch dimension
img_array /= 255.   #Normalize the pixel values   -zoomin/out
#Make predictions
prediction = model.predict(img_array)
#print the prediction
print(prediction)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# [[0.4840891]]

# %%
if prediction < 0.5:
  print("Prediction: No Tumor (P robability: )",prediction[0][0])
else:
  print("Prediction: Tumor Present (Probability: )",prediction[0][0])
# Out:
# Prediction: No Tumor (P robability: ) 0.4840891
