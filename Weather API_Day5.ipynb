# %%
import requests as rq

# %%
api_key = '5162dabc122948aea6e53631242802'

# %%
city = 'London'
url =f'http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'
response = rq.get(url)
data = response.json()
print(data)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1709101691, 'localtime': '2024-02-28 6:28'}, 'current': {'last_updated_epoch': 1709100900, 'last_updated': '2024-02-28 06:15', 'temp_c': 6.0, 'temp_f': 42.8, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 3.8, 'wind_kph': 6.1, 'wind_degree': 130, 'wind_dir': 'SE', 'pressure_mb': 1019.0, 'pressure_in': 30.09, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 100, 'cloud': 50, 'feelslike_c': 4.7, 'feelslike_f': 40.5, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 7.2, 'gust_kph': 11.6}}

# %%
type(data)
# Out:
# dict

# %%
print("City:",data['location']['name'])
# Out:
# City: London

# %%
print("State:",data['location']['region'])
# Out:
# State: City of London, Greater London

# %%
print("Country:",data['location']['country'])
print("Temperature in C:",data['current']['temp_c'])
print("Feels: ",data['current']['feelslike_c'])
print("Wind Direction:",data['current']['wind_mph'])
print("Humidity:",data['current']['humidity'])
# Out:
# Country: United Kingdom
# Temperature in C: 6.0
# Feels:  4.7
# Wind Direction: 3.8
# Humidity: 100

# %%
city = input("Enter a city name:")
api_key = '5162dabc122948aea6e53631242802'
url =f'http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'
response = rq.get(url)
data = response.json()
print(type(data))
if data['error']['code'] == 1006:
  print("No location is found.")
else:
  print("City:",data['location']['name'])
  print("State:",data['location']['region'])
  print("Country:",data['location']['country'])
  print("Temperature in C:",data['current']['temp_c'])
  print("Feels: ",data['current']['feelslike_c'])
  print("Wind Direction:",data['current']['wind_mph'])
  print("Humidity:",data['current']['humidity'])
  print("Cloud: ",data['current']['cloud'])
# Out:
# Enter a city name:jyf
# <class 'dict'>
# No location is found.

# %%
city = input("Enter a city name:")
api_key = '5162dabc122948aea6e53631242802'
url =f'http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'
response = rq.get(url)
data = response.json()
print(type(data))
if response.status_code == 200:

  print(f"weather in {city}:")
  print("City:",data['location']['name'])
  print("State:",data['location']['region'])
  print("Country:",data['location']['country'])
  print("Temperature in C:",data['current']['temp_c'])
  print("Feels: ",data['current']['feelslike_c'])
  print("Wind Direction:",data['current']['wind_mph'])
  print("Humidity:",data['current']['humidity'])
  print("Cloud: ",data['current']['cloud'])
else:
  print(data['error']['message'])

# %% [markdown]
# **HOMEWORK**

# %%
import requests


url = f"https://currencyconverter.p.rapidapi.com/availablecurrencies"

headers = {
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "currencyconverter.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests
import json

url = f"https://currencyconverter.p.rapidapi.com/"

querystring = {"from_amount":"1","from":"USD","to":"SEK"}

headers = {
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "currencyconverter.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = f'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-28T15:50:22.850Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 4233, 'name': 'zjybxrwv7ts', 'symbol': '4i3evjz85nb', 'slug': '0dk9ed20o3s', 'cmc_rank': 8844, 'num_market_pairs': 6735, 'circulating_supply': 9369, 'total_supply': 1505, 'max_supply': 5670, 'infinite_supply': None, 'last_updated': '2024-02-28T15:50:22.850Z', 'date_added': '2024-02-28T15:50:22.850Z', 'tags': ['vl8o06kltds', 'v93oqby0mu', '50saa5z1ip', 'xi81zj52wp', 'oon78ezmgz', 'fjtyk5awa5', 'q80gzjdcgkr', 'sc9drlvx5j8', '6h81drng2zx', 'zjl387vf0x'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5727074445694125, 'volume_24h': 4344, 'volume_change_24h': 0.033068294568178835, 'percent_change_1h': 0.836477362270551, 'percent_change_24h': 0.5966104599343758, 'percent_change_7d': 0.8448982941107606, 'market_cap': 0.19106512521411667, 'market_cap_dominance
# ...

# %%
import requests

url = "https://joke3.p.rapidapi.com/v1/joke/%7Bid%7D"

headers = {
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "joke3.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests

url = "https://article-extractor-and-summarizer.p.rapidapi.com/summarize"

querystring = {"url":"https://www.geeksforgeeks.org/dbms/","length":"3"}

headers = {
	"X-RapidAPI-Key": "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c",
	"X-RapidAPI-Host": "article-extractor-and-summarizer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'summary': 'The text provides a comprehensive overview of various topics related to database management systems (DBMS). It covers indexing and its types, including B-Tree, B+ Tree, bitmap indexing, inverted index, and SQL queries on clustered and non-clustered indexes. It also delves into file organization, advanced topics such as RAID, query optimization, and password storage in databases, as well as data warehousing, data mining, and ODBMS.\n\nOne of the key advantages of learning DBMS is its ability to organize and manage data efficiently, providing features for data manipulation, security, improved decision-making, and consistency. The text also includes frequently asked questions (FAQs) on DBMS, covering topics such as the definition of a database, different languages present in DBMS (DDL, DML, DCL, TCL), ACID properties in DBMS, and the advantages of DBMS, including data sharing, integrity, data independence, and data security.\n\nOverall, the text serves as a valuable resourc
# ...

# %%
import requests

url = "https://numbersapi.p.rapidapi.com/6/21/date"

querystring = {"fragment":"true","json":"true"}

headers = {
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "numbersapi.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'text': 'James Otis, Jr. offends the King and Parliament in a speech to the Massachusetts General Court', 'year': 1768, 'number': 173, 'found': True, 'type': 'date'}

# %%
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2/languages"

headers = {
	"Accept-Encoding": "application/gzip",
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "google-translate1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'data': {'languages': [{'language': 'af'}, {'language': 'ak'}, {'language': 'am'}, {'language': 'ar'}, {'language': 'as'}, {'language': 'ay'}, {'language': 'az'}, {'language': 'be'}, {'language': 'bg'}, {'language': 'bho'}, {'language': 'bm'}, {'language': 'bn'}, {'language': 'bs'}, {'language': 'ca'}, {'language': 'ceb'}, {'language': 'ckb'}, {'language': 'co'}, {'language': 'cs'}, {'language': 'cy'}, {'language': 'da'}, {'language': 'de'}, {'language': 'doi'}, {'language': 'dv'}, {'language': 'ee'}, {'language': 'el'}, {'language': 'en'}, {'language': 'eo'}, {'language': 'es'}, {'language': 'et'}, {'language': 'eu'}, {'language': 'fa'}, {'language': 'fi'}, {'language': 'fr'}, {'language': 'fy'}, {'language': 'ga'}, {'language': 'gd'}, {'language': 'gl'}, {'language': 'gn'}, {'language': 'gom'}, {'language': 'gu'}, {'language': 'ha'}, {'language': 'haw'}, {'language': 'he'}, {'language': 'hi'}, {'language': 'hmn'}, {'language': 'hr'}, {'language': 'ht'}, {'language': 'hu'}, {'langu
# ...

# %%
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

payload = {
	"q": "Hello, world!",
	"target": "ar",
	"source": "en"
}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"Accept-Encoding": "application/gzip",
	"X-RapidAPI-Key": "1a9f349e1emsh1b89137f5970633p1cef2ejsn05b510a53a75",
	"X-RapidAPI-Host": "google-translate1.p.rapidapi.com"
}

response = requests.post(url, data=payload, headers=headers)

print(response.json())
# Out:
# {'data': {'translations': [{'translatedText': 'مرحبا بالعالم!'}]}}
