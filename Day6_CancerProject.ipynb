# %% [markdown]
# **DECISION** **TREE** **CLASSIFIER**

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
model1 = DecisionTreeClassifier()
from sklearn.tree import export_graphviz,plot_tree

# %%
cncrdf = pd.read_csv("/content/cancer patient data sets.csv")
cncrdf
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                       4             3                     2  ...        3
# 1                       3             4                     2  ...        1
# 2                       5             5                     4  ...        8
# 3                       7             6                     7  ...        4
# 4                       7             7                     6  ...        3
# ..                    ...           ...                   ...  ...      ...
# 995                     7             7                     6  ...        5
# 996                     7             7                     6  ...        9
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 995            3                    2         7                      8
# 996            6                    5         7                      2
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 995                         2              4          5        3    High
# 996                         4              3          1        4    High
# 997                         4              6          7        2    High
# 998                         2              4          2        3    High
# 999                         4              6          7        2    High
#
# [1000 rows x 26 columns]

# %%
feature_col = ["chronic Lung Disease","Smoking","Chest Pain","Dry Cough"]
features = cncrdf[feature_col]  #features
target = cncrdf.Level   #target variables

# %%
model1.fit(features,target)
# Out:
# DecisionTreeClassifier()

# %%
model1.predict([[2,3,2,3]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Low'], dtype=object)

# %%
CLD = int(input("Enter Chronic Lung Disease:"))
Smk = int(input("Enter Smoking: "))
CP  = int(input("Enter Chest Pain: "))
DC = int(input("Enter Dry Cough: "))
pred = model1.predict([[CLD,Smk,CP,DC]])
if pred== "Low":
  print("You dont have Cancer")
else:
  print("You have Cancer")
# Out:
# Enter Chronic Lung Disease:2
# Enter Smoking: 3
# Enter Chest Pain: 2
# Enter Dry Cough: 3
# You dont have Cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(model1)
# Out:
# [Text(0.6571428571428571, 0.9545454545454546, 'x[1] <= 6.5\ngini = 0.665\nsamples = 1000\nvalue = [365, 303, 332]'),
#  Text(0.42857142857142855, 0.8636363636363636, 'x[3] <= 5.5\ngini = 0.609\nsamples = 704\nvalue = [99, 283, 322]'),
#  Text(0.2571428571428571, 0.7727272727272727, 'x[2] <= 1.5\ngini = 0.517\nsamples = 554\nvalue = [10, 262, 282]'),
#  Text(0.2, 0.6818181818181818, 'gini = 0.0\nsamples = 70\nvalue = [0, 70, 0]'),
#  Text(0.3142857142857143, 0.6818181818181818, 'x[0] <= 1.5\ngini = 0.503\nsamples = 484\nvalue = [10, 192, 282]'),
#  Text(0.2571428571428571, 0.5909090909090909, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.37142857142857144, 0.5909090909090909, 'x[3] <= 2.5\ngini = 0.479\nsamples = 444\nvalue = [10, 152, 282]'),
#  Text(0.22857142857142856, 0.5, 'x[0] <= 6.5\ngini = 0.289\nsamples = 171\nvalue = [0, 30, 141]'),
#  Text(0.17142857142857143, 0.4090909090909091, 'x[1] <= 2.5\ngini = 0.218\nsamples = 161\nvalue = [0, 20, 141]'),
#  Text(0.11428571428571428, 0.3181818181818182, 'x[2] <= 2.5\ngini = 0.375\nsamples = 80\nvalue = [0, 20, 60]'),
#  Text(0.05714285714285714, 0.22727272727272727, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50]'),
#  Text(0.17142857142857143, 0.22727272727272727, 'x[0] <= 4.5\ngini = 0.444\nsamples = 30\nvalue = [0, 20, 10]'),
#  Text(0.11428571428571428, 0.13636363636363635, 'x[1] <= 1.5\ngini = 0.5\nsamples = 20\nvalue = [0, 10, 10]'),
#  Text(0.05714285714285714, 0.045454545454545456, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.17142857142857143, 0.045454545454545456, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10]'),
#  Text(0.22857142857142856, 0.13636363636363635, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.22857142857142856, 0.3181818181818182, 'gini = 0.0\nsamples = 81\nvalue = [0, 0, 81]'),
#  Text(0.2857142857142857, 0.4090909090909091, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.5142857142857142, 0.5, 'x[3] <= 3.5\ngini = 0.532\nsamples = 273\nvalue = [10, 122, 141]'),
#  Text(0.45714285714285713, 0.4090909090909091, 'gini = 0.0\nsamples = 61\nvalue = [0, 61, 0]'),
#  Text(0.5714285714285714, 0.4090909090909091, 'x[2] <= 6.5\ngini = 0.473\nsamples = 212\nvalue = [10, 61, 141]'),
#  Text(0.45714285714285713, 0.3181818181818182, 'x[0] <= 5.5\ngini = 0.39\nsamples = 192\nvalue = [0, 51, 141]'),
#  Text(0.4, 0.22727272727272727, 'x[0] <= 2.5\ngini = 0.487\nsamples = 122\nvalue = [0, 51, 71]'),
#  Text(0.34285714285714286, 0.13636363636363635, 'gini = 0.0\nsamples = 51\nvalue = [0, 0, 51]'),
#  Text(0.45714285714285713, 0.13636363636363635, 'x[2] <= 5.0\ngini = 0.405\nsamples = 71\nvalue = [0, 51, 20]'),
#  Text(0.4, 0.045454545454545456, 'gini = 0.0\nsamples = 51\nvalue = [0, 51, 0]'),
#  Text(0.5142857142857142, 0.045454545454545456, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20]'),
#  Text(0.5142857142857142, 0.22727272727272727, 'gini = 0.0\nsamples = 70\nvalue = [0, 0, 70]'),
#  Text(0.6857142857142857, 0.3181818181818182, 'x[0] <= 6.5\ngini = 0.5\nsamples = 20\nvalue = [10, 10, 0]'),
#  Text(0.6285714285714286, 0.22727272727272727, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(0.7428571428571429, 0.22727272727272727, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.6, 0.7727272727272727, 'x[0] <= 3.0\ngini = 0.557\nsamples = 150\nvalue = [89, 21, 40]'),
#  Text(0.5428571428571428, 0.6818181818181818, 'x[3] <= 6.5\ngini = 0.451\nsamples = 61\nvalue = [0, 21, 40]'),
#  Text(0.4857142857142857, 0.5909090909090909, 'gini = 0.0\nsamples = 21\nvalue = [0, 21, 0]'),
#  Text(0.6, 0.5909090909090909, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 40]'),
#  Text(0.6571428571428571, 0.6818181818181818, 'gini = 0.0\nsamples = 89\nvalue = [89, 0, 0]'),
#  Text(0.8857142857142857, 0.8636363636363636, 'x[0] <= 5.5\ngini = 0.187\nsamples = 296\nvalue = [266, 20, 10]'),
#  Text(0.8285714285714286, 0.7727272727272727, 'x[3] <= 4.5\ngini = 0.625\nsamples = 40\nvalue = [10, 20, 10]'),
#  Text(0.7714285714285715, 0.6818181818181818, 'gini = 0.0\nsamples = 20\nvalue = [0, 20, 0]'),
#  Text(0.8857142857142857, 0.6818181818181818, 'x[1] <= 7.5\ngini = 0.5\nsamples = 20\nvalue = [10, 0, 10]'),
#  Text(0.8285714285714286, 0.5909090909090909, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(0.9428571428571428, 0.5909090909090909, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10]'),
#  Text(0.9428571428571428, 0.7727272727272727, 'gini = 0.0\nsamples = 256\nvalue = [256, 0, 0]')]

# %% [markdown]
# **RANDOM** **FOREST**

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators=10)

# %%
cncrdf = pd.read_csv("/content/cancer patient data sets.csv")
cncrdf
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                       4             3                     2  ...        3
# 1                       3             4                     2  ...        1
# 2                       5             5                     4  ...        8
# 3                       7             6                     7  ...        4
# 4                       7             7                     6  ...        3
# ..                    ...           ...                   ...  ...      ...
# 995                     7             7                     6  ...        5
# 996                     7             7                     6  ...        9
# 997                     5             5                     4  ...        8
# 998                     7             7                     6  ...        3
# 999                     5             5                     4  ...        8
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0              4                    2         2                      3
# 1              3                    7         8                      6
# 2              7                    9         2                      1
# 3              2                    3         1                      4
# 4              2                    4         1                      4
# ..           ...                  ...       ...                    ...
# 995            3                    2         7                      8
# 996            6                    5         7                      2
# 997            7                    9         2                      1
# 998            2                    4         1                      4
# 999            7                    9         2                      1
#
#      Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                           1              2          3        4     Low
# 1                           2              1          7        2  Medium
# 2                           4              6          7        2    High
# 3                           5              6          7        5    High
# 4                           2              4          2        3    High
# ..                        ...            ...        ...      ...     ...
# 995                         2              4          5        3    High
# 996                         4              3          1        4    High
# 997                         4              6          7        2    High
# 998                         2              4          2        3    High
# 999                         4              6          7        2    High
#
# [1000 rows x 26 columns]

# %%
feature_col = ["chronic Lung Disease","Smoking","Chest Pain","Dry Cough"]
features1 = cncrdf[feature_col]  #features
target1 = cncrdf.Level   #target variables

# %%
model2.fit(features1,target1)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
model2.predict([[2,2,2,7]])
#model2.predict([[6,8,7,2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Medium'], dtype=object)

# %%
CLD = int(input("Enter Chronic Lung Disease:"))
Smk = int(input("Enter Smoking: "))
CP  = int(input("Enter Chest Pain: "))
DC = int(input("Enter Dry Cough: "))
pred1 = model2.predict([[CLD,Smk,CP,DC]])
if pred1== "Low":
  print("You dont have Cancer")
else:
  print("You have Cancer")
# Out:
# Enter Chronic Lung Disease:6
# Enter Smoking: 8
# Enter Chest Pain: 7
# Enter Dry Cough: 2
# You have Cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
model2.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=904666321),
#  DecisionTreeClassifier(max_features='sqrt', random_state=185649264),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1416587190),
#  DecisionTreeClassifier(max_features='sqrt', random_state=587658897),
#  DecisionTreeClassifier(max_features='sqrt', random_state=780124618),
#  DecisionTreeClassifier(max_features='sqrt', random_state=967178977),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1460431499),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1888727059),
#  DecisionTreeClassifier(max_features='sqrt', random_state=913628472),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1381598808)]

# %%
for i, tree in enumerate(model2.estimators_):
  tree_dot_file = os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file = os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=["chronic Lung Disease","Smoking","Chest Pain","Dry Cough"],
                    class_names=[str(cls) for cls in model2.classes_], filled=True, rounded=True)

# %%
command = f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 9 visualization saved to tree_visualizations/tree_9.png

# %% [markdown]
# **LINEAR** **REGRESSION**  doesnt take strings

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
model3 = LinearRegression()
from matplotlib import pyplot as plt
