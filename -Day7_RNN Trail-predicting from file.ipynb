# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
import pandas as pd
df = pd.read_csv("/content/Earth.txt",sep=',')
df
# Out:
# Empty DataFrame
# Columns: [Earth is the third planet from the Sun and the only astronomical object known to harbor life. This is enabled by Earth being a water world,  the only one in the Solar System sustaining liquid surface water. Almost all of Earth's water is contained in its global ocean,  covering 70.8% of Earth's crust. The remaining 29.2% of Earth's crust is land,  most of which is located in the form of continental landmasses within one hemisphere,  Earth's land hemisphere. Most of Earth's land is somewhat humid and covered by vegetation,  while large sheets of ice at Earth's polar deserts retain more water than Earth's groundwater,  lakes,  rivers and atmospheric water combined. Earth's crust consists of slowly moving tectonic plates,  which interact to produce mountain ranges,  volcanoes,  and earthquakes. Earth has a liquid outer core that generates a magnetosphere capable of deflecting most of the destructive solar winds and cosmic radiation.]
# Index: []

# %%
#Generating some example sequential data
sentences = ['I love learning','I love python','I hate school','Recurrent Nueral Networks are powerful']

# %%
#Tokenizing the words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df)
total_words = len(tokenizer.word_index) + 1
print(total_words)
# Out:
# 96

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in df:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[7, 4],
#  [7, 4, 2],
#  [7, 4, 2, 21],
#  [7, 4, 2, 21, 22],
#  [7, 4, 2, 21, 22, 23],
#  [7, 4, 2, 21, 22, 23, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4, 31],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4, 31, 15],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8,
#   6],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8,
#   6,
#   33],
#  [2, 13],
#  [2, 13, 16],
#  [2, 13, 16, 9],
#  [2, 13, 16, 9, 2],
#  [2, 13, 16, 9, 2, 17],
#  [2, 13, 16, 9, 2, 17, 34],
#  [2, 13, 16, 9, 2, 17, 34, 35],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9, 40],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9, 40, 41],
#  [2,
#   13,
#   16,
#   9,
#   2,
#   17,
#   34,
#   35,
#   18,
#   36,
#   6,
#   37,
#   38,
#   1,
#   3,
#   6,
#   4,
#   39,
#   9,
#   40,
#   41,
#   42],
#  [43, 44],
#  [43, 44, 45],
#  [43, 44, 45, 1],
#  [43, 44, 45, 1, 3],
#  [43, 44, 45, 1, 3, 10],
#  [43, 44, 45, 1, 3, 10, 2],
#  [43, 44, 45, 1, 3, 10, 2, 46],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10, 4],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10, 4, 11],
#  [12, 1],
#  [12, 1, 19],
#  [12, 1, 19, 4],
#  [12, 1, 19, 4, 49],
#  [12, 1, 19, 4, 49, 9],
#  [12, 1, 19, 4, 49, 9, 2],
#  [12, 1, 19, 4, 49, 9, 2, 50],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16, 20],
#  [3, 11],
#  [3, 11, 20],
#  [3, 11, 20, 12],
#  [3, 11, 20, 12, 1],
#  [3, 11, 20, 12, 1, 3],
#  [3, 11, 20, 12, 1, 3, 11],
#  [3, 11, 20, 12, 1, 3, 11, 4],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56, 15],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57],
#  [58, 59],
#  [58, 59, 60],
#  [58, 59, 60, 1],
#  [58, 59, 60, 1, 61],
#  [58, 59, 60, 1, 61, 62],
#  [58, 59, 60, 1, 61, 62, 3],
#  [58, 59, 60, 1, 61, 62, 3, 63],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67, 3],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67, 3, 68],
#  [70, 5],
#  [70, 5, 71],
#  [70, 5, 71, 6],
#  [70, 5, 71, 6, 72],
#  [70, 5, 71, 6, 72, 3],
#  [70, 5, 71, 6, 72, 3, 10],
#  [70, 5, 71, 6, 72, 3, 10, 73],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75, 76],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75, 76, 77],
#  [19, 78],
#  [19, 78, 14],
#  [19, 78, 14, 79],
#  [19, 78, 14, 79, 80],
#  [19, 78, 14, 79, 80, 81],
#  [5, 83],
#  [5, 83, 7],
#  [5, 83, 7, 84],
#  [5, 83, 7, 84, 8],
#  [5, 83, 7, 84, 8, 18],
#  [5, 83, 7, 84, 8, 18, 85],
#  [5, 83, 7, 84, 8, 18, 85, 86],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17, 93],
#  [5,
#   83,
#   7,
#   84,
#   8,
#   18,
#   85,
#   86,
#   87,
#   88,
#   8,
#   89,
#   90,
#   1,
#   91,
#   12,
#   1,
#   2,
#   92,
#   17,
#   93,
#   5],
#  [5,
#   83,
#   7,
#   84,
#   8,
#   18,
#   85,
#   86,
#   87,
#   88,
#   8,
#   89,
#   90,
#   1,
#   91,
#   12,
#   1,
#   2,
#   92,
#   17,
#   93,
#   5,
#   94],
#  [5,
#   83,
#   7,
#   84,
#   8,
#   18,
#   85,
#   86,
#   87,
#   88,
#   8,
#   89,
#   90,
#   1,
#   91,
#   12,
#   1,
#   2,
#   92,
#   17,
#   93,
#   5,
#   94,
#   95]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  7,  4],
#        [ 0,  0,  0, ...,  7,  4,  2],
#        [ 0,  0,  0, ...,  4,  2, 21],
#        ...,
#        [ 0,  0,  0, ..., 17, 93,  5],
#        [ 0,  0,  0, ..., 93,  5, 94],
#        [ 0,  0,  5, ...,  5, 94, 95]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
#compiling the model
model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#Training the model
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 2s - loss: 4.5795 - accuracy: 0.0000e+00 - 2s/epoch - 488ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 4.3890 - accuracy: 0.0929 - 85ms/epoch - 17ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 4.2105 - accuracy: 0.1071 - 96ms/epoch - 19ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 4.1017 - accuracy: 0.1357 - 81ms/epoch - 16ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.9529 - accuracy: 0.1714 - 84ms/epoch - 17ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.8561 - accuracy: 0.2214 - 82ms/epoch - 16ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 3.7083 - accuracy: 0.2714 - 88ms/epoch - 18ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 3.5830 - accuracy: 0.3071 - 87ms/epoch - 17ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 3.4486 - accuracy: 0.3214 - 87ms/epoch - 17ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 3.3200 - accuracy: 0.3929 - 88ms/epoch - 18ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 3.2094 - accuracy: 0.3786 - 82ms/epoch - 16ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 3.0303 - accuracy: 0.4357 - 86ms/epoch - 17ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.9192 - accuracy: 0.5071 - 89ms/epoch - 18ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.7649 - accuracy: 0.5357 - 98ms/epoch - 20ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.6194 - accuracy: 0.5929 - 82ms/epoch - 16ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.4894 - accuracy: 0.6000 - 83ms/epoch - 17ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 2.3488 - accuracy: 0.6357 - 84ms/epoch - 17ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 2.2387 - accuracy: 0.6857 - 94ms/epoch - 19ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 2.0931 - accuracy: 0.7143 - 83ms/epoch - 17ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.9791 - accuracy: 0.7071 - 85ms/epoch - 17ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.8570 - accuracy: 0.7357 - 82ms/epoch - 16ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.7445 - accuracy: 0.7357 - 85ms/epoch - 17ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.6477 - accuracy: 0.7714 - 83ms/epoch - 17ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.5477 - accuracy: 0.7714 - 93ms/epoch - 19ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4457 - accuracy: 0.7857 - 98ms/epoch - 20ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3619 - accuracy: 0.8000 - 82ms/epoch - 16ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.2792 - accuracy: 0.7857 - 85ms/epoch - 17ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2236 - accuracy: 0.8286 - 83ms/epoch - 17ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.1570 - accuracy: 0.7857 - 88ms/epoch - 18ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.0918 - accuracy: 0.8071 - 84ms/epoch - 17ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.0428 - accuracy: 0.8571 - 84ms/epoch - 17ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.9761 - accuracy: 0.8500 - 83ms/epoch - 17ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.9128 - accuracy: 0.8571 - 82ms/epoch - 16ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.8621 - accuracy: 0.9071 - 86ms/epoch - 17ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.8152 - accuracy: 0.8929 - 88ms/epoch - 18ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.7641 - accuracy: 0.9000 - 81ms/epoch - 16ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.7438 - accuracy: 0.8857 - 97ms/epoch - 19ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.7122 - accuracy: 0.9214 - 90ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6745 - accuracy: 0.9000 - 89ms/epoch - 18ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.6552 - accuracy: 0.8857 - 87ms/epoch - 17ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.6218 - accuracy: 0.9143 - 84ms/epoch - 17ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.6061 - accuracy: 0.9286 - 84ms/epoch - 17ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5547 - accuracy: 0.9357 - 83ms/epoch - 17ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5313 - accuracy: 0.9429 - 82ms/epoch - 16ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5168 - accuracy: 0.9214 - 85ms/epoch - 17ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.4883 - accuracy: 0.9357 - 90ms/epoch - 18ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.4652 - accuracy: 0.9357 - 83ms/epoch - 17ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4481 - accuracy: 0.9286 - 97ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4372 - accuracy: 0.9571 - 89ms/epoch - 18ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4192 - accuracy: 0.9500 - 82ms/epoch - 16ms/step

# %%
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: lavs
# Enter how many words to predict: 12
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# lavs is is in the the the the the the liquid the crust
